# %% [markdown]
# # Importation of documents from Open Science sources

# %% [markdown]
# ---
# ## <a name="Repositorio">Repositorio</a> (Spain, UNICT)
# ---
#
# This document shows the data provided by Repositorio and  how to get data with a specific request.
#
# ---
#  - Need to be register : Yes
#  - API : Yes (for the DSpace tool)
#  - Cost : Free
#  - Documentation : Yes (in spannish and english (translated) )
#  - Access : simple GET request
#  - Ref biblio : no (to build from the data)
#  - answer format : JSON
#
# - fields : authors, abstract, date, .....

# %% [markdown]
# ---
# The api is working, but the query is not easy to use : it needs some steps :
#  - find the communities, choose the best one
#  - find the collections, choose the best one
#  - find the articles, select one
#
# But, the website provide the list of all the articles in a CSV file. As it is easy to interact with it in python, we can use it.
#
# The code to interact with the API is accessible at [#queries](the bottom of this page).

# %% [markdown]
# ---
# ### Use of CSV file
# Here, we extract  the data from the "publicaciones.csv" file and we build a new csv file with the headers `` 'title', 'keywords', 'abstract', 'field', 'authors', 'date', 'doi', 'references'``.
# The objective is to store the data of the different repositories in a same format.

# %%
from tqdm import tqdm
import requests
import pandas as pd
doc_publicaciones = pd.read_csv("publicaciones.csv")
doc_publicaciones.keys()
# Out:
# Index(['title', 'dateIssued', 'publisher', 'issn', 'isbn', 'doi', 'abstract',
#        'authorList', 'Relates_ResearchGroup'],
#       dtype='object')

# %% [markdown]
# So, it is relatively simple. Only the domain (field) and the references are missing.. This can be obtain for the DOI.

# %%
#we choose these data from DOI (we could have more (pdf if provided, ....))
doi_keys = ["title","author","subject", "reference"]

def get_info_from_doi(doi):
    """return an extract of the DOI data"""
    doi_info = {}
    if doi[-1] == '.': doi = doi[:-1]
    url = f"https://api.crossref.org/works/{doi}"
    response = requests.get(url)
    # check if success
    if response.status_code == 200:
        # extract  JSON data 
        data = response.json()
        data = data["message"]
        for key in doi_keys:
            doi_info[key] = data[key] if key in data else ""
    return doi_info

# %%
#we crfeate the new entries from the one of repositorio
#from ['title', 'dateIssued', 'publisher', 'issn', 'isbn', 'doi', 'abstract', 'authorList', 'Relates_ResearchGroup'],
#to ['title', 'keywords', 'abstract', 'field', 'authors', 'date', 'doi', 'references']
new_rows = []
for index, row in doc_publicaciones.iterrows():
    new_row = {}
    new_row["title"] = str(row['title']) if 'title' in row else ""
    new_row["keywords"] = ""
    new_row["abstract"] = str(row['abstract'])  if 'abstract' in row else ""
    new_row["date"] = str(row['dateIssued'])  if 'dateIssued' in row else ""
    new_row["authors"] = str(row['authorList'])  if 'authorList' in row else ""
    new_row["doi"] = str(row['doi'])  if 'doi' in row else ""
    new_rows.append(new_row)

# %%
#we miss the field and references : ask for them
for publication in tqdm(new_rows):
    field  = ""
    doi = publication.get('doi', '')
    references = ""    
    if(doi!="" and doi!="nan"):
        doi_values = get_info_from_doi(doi)
        #get the field "subject" if exists  
        if 'subject' in doi_values: field = doi_values['subject']
        if 'reference' in doi_values: 
            refs = doi_values['reference']
            for ref in refs:
                if 'DOI' in ref:
                    references = references + ref['DOI'] + ", "
    publication['field'] = ",".join(field)
    publication['references'] = references
# Out:
# 100%|██████████| 8270/8270 [1:09:42<00:00,  1.98it/s]

# %%
new_rows
# Out:
# [{'title': 'Design and verification of integrated circuitry for real-time frailty monitoring',
#   'keywords': '',
#   'abstract': 'In this study, a new wireless electronic circuitry to analyze weight distribution was designed and incorporated into a chair to gather data related to common human postures (sitting and standing up). These common actions have a significant impact on various motor capabilities, including gait parameters, fall risk, and information on sarcopenia. The quality of these actions lacks an absolute measurement, and currently, there is no qualitative and objective metric for it. To address this, the designed analyzer introduces variables like Smoothness and Percussion to provide more information and objectify measurements in the assessment of stand-up/sit-down actions. Both the analyzer and the proposed variables offer additional information that can objectify assessments depending on the clinical eye of the physicians.',
#   'date': '20/12/2024',
#   'authors': 'LUIS RODRIGUEZ COBO; GUILLERMO DIAZ SAN MARTIN; JOSÉ FRANCISCO ALGORRI GENARO; CARLOS FERNANDEZ VIADERO; JOSE MIGUEL LOPEZ HIGUERA; ADOLFO COBO GARCIA;',
#   'doi': '10.3390/s24010029',
#   'field': 'Electrical and Electronic Engineering,Biochemistry,Instrumentation,Atomic and Molecular Physics, and Optics,Analytical Chemistry',
#   'references': '10.1111/ggi.12766, 10.1007/s00421-003-0837-z, 10.1016/j.arr.2021.101399, 10.1109/JTEHM.2016.2620177, 10.1016/j.maturitas.2022.07.011, 10.1016/j.jamda.2018.02.003, 10.1016/j.jamda.2013.11.027, 10.1016/0268-0033(94)90020-5, 10.1111/jgs.17002, 10.1007/s12603-020-1427-z, 10.1016/j.apmr.2008.06.028, 10.1016/j.ajem.2018.06.015, 10.1159/000314963, 10.1186/s12877-020-01642-4, 10.1186/s12877-021-02147-4, 10.1016/0268-0033(94)90004-3, 10.1093/ageing/afq034, 10.3390/s23208646, 10.5334/paah.241, '},
#  {'title': 'Structural safety assessment criteria for dismantling operations of unique structures. San Mames roof arch experience',
#   'keywords': '',
#   'abstract': 'Dismantling is a fundamental phase of the life cycle on transport infrastructures and buildings in terms of sustainability and environmental impact but also in terms of structural safety. The requirements of the dismantling operation of a structure are linked to the complexity of the structure, and it is necessary to monitor the evolution of its structural behavior to avoid unexpected and demanding conditions and facilitate it reuse in the future. The authors present (1) an optimal methodology for the approach to the dismantling project of a structure, (2) a new global structural safety indicator for real time assessment, as well as (3) its application in the dismantling of the San Mames arch roof. The application of the vibrating chord technique in order to obtain the existing stresses in the lower tie rod of the arch of the San Mames roof arch and the monitoring of the evolution of the stresses in this tie rod during the operation of lifting and dismantling of the roof arch is presented. As a result, the paper contributes to reducing the lack of shared experience in the sector, as it is one of the few in the literature on the dismantling of large structural elements.',
#   'date': '01/05/2024',
#   'authors': 'ALVARO GAUTE ALONSO; DAVID GARCIA SANCHEZ;',
#   'doi': '10.1016/j.jobe.2024.108617',
#   'field': 'Mechanics of Materials,Safety, Risk, Reliability and Quality,Building and Construction,Architecture,Civil and Structural Engineering',
#   'abstract': 'Polarization-Sensitive Optical Coherence Tomography (PS-OCT) is a widely-used technique for high-resolution material characterization since it allows for real-time structural analysis and imperfections identification. Nevertheless, when the sample is too big or imperfections are not on the micrometric scale, PS-OCT imaging can become too complex to be performed on a regular basis. Alternatively, polarimetric camera (PCam) imaging can obtain polarization measurements of a sample at a macroscopic scale, allowing for a faster and cheaper inspection of the sample. In doing so, the depth-profiling capabilities of PS-OCT would be forfeited, as well as the ability to measure other than the linear polarization qualities of the light beam. This paper compares the data that can be easily extracted from a PCam, with the complete and more complex characterization of the polarization of light that can be obtained with a PS-OCT device. The comparison of both systems is assessed through the evaluation of their performance when measuring different stress states of a sample.',
#   'date': '01/04/2024',
#   'authors': 'VERONICA MIEITES ALONSO; JOSE  ALBERTO GUTIERREZ GUTIERREZ; ARTURO PARDO FRANCO; JOSE MIGUEL LOPEZ HIGUERA; OLGA MARIA CONDE PORTILLA;',
#   'doi': '10.1016/j.optlaseng.2023.107985',
#   'field': 'Electrical and Electronic Engineering,Mechanical Engineering,Atomic and Molecular Physics, and Optics,Electronic, Optical and Magnetic Materials',
#   'references': '10.1111/j.1365-2818.2012.03619.x, 10.1097/ICU.0b013e32835f8bf8, 10.1002/tbio.202000012, 10.1038/sj.eye.6700729, 10.1038/s41377-022-00740-9, 10.1016/j.mspro.2015.04.018, 10.1179/sic.2009.54.2.117, 10.2351/7.0000336, 10.1016/j.ijleo.2022.168784, 10.1590/S0103-64402010000500008, 10.1109/ACCESS.2018.2882527, 10.1016/j.jdent.2011.05.005, 10.1364/BOE.8.001838, 10.1126/science.1957169, 10.1016/j.actamat.2005.02.034, 10.1016/j.compscitech.2007.04.018, 10.1007/s00339-002-2065-5, 10.1016/0262-8856(95)94383-B, 10.1016/j.optlaseng.2021.106770, 10.1016/j.optlaseng.2023.107737, 10.1016/j.optlaseng.2023.107721, 10.1016/j.optlaseng.2020.106256, 10.1016/j.optlaseng.2021.106724, 10.1016/j.optlaseng.2020.106088, 10.1016/j.optlaseng.2023.107526, 10.1016/j.measurement.2022.111727, 10.1364/AO.45.005453, '},
#  {'title': 'Liquid crystal anisotropic axicon for the generation of non-diffracting Bessel beams with longitudinally varying polarization',
#   'keywords': '',
#   'abstract': 'In this work we demonstrate a tunable liquid-crystal element of linear phase profile along the radial coordinate. In combination with a regular refractive axicon, it behaves as an anisotropic axicon, generating the collinear superposition of two orthogonally polarized Bessel beams with different propagation constant. This superposition results in a Bessel beam where the state of polarization (SOP) varies periodically along propagation. Experimental results probe the voltage control of the SOP oscillating period, which agree well with theory. This compound axicon is a very compact and efficient way of generating Bessel beams with polarization modulation, thus representing a significant advantage over other methods reported in the literature that require bulk optical systems based on spatial light modulators.',
#   'date': '01/03/2024',
#   'authors': 'JOSÉ FRANCISCO ALGORRI GENARO; IGNACIO MORENO SORIANO;',
#   'doi': '10.1016/j.optlastec.2023.110255',
#   'field': 'Electrical and Electronic Engineering,Atomic and Molecular Physics, and Optics,Electronic, Optical and Magnetic Materials',
#   'references': '10.1364/JOSAA.4.000651, 10.1103/PhysRevLett.58.1499, 10.1016/S0030-4018(00)00961-5, 10.1080/0010751042000275259, 10.1016/S0030-4018(01)01479-1, 10.1364/OL.33.001696, 10.1002/lpor.201100031, 10.1109/JLT.2022.3172134, 10.1038/ncomms4248, 10.1002/lpor.201900103, 10.1117/12.60017, 10.1109/JLT.2010.2043413, 10.1063/1.5009760, 10.1364/AO.32.006368, 10.1080/09500340408232522, 10.1364/OL.39.003476, 10.1038/s41598-023-29164-0, 10.1364/OE.17.015558, 10.1088/2040-8986/aad155, 10.1364/OE.438709, 10.1364/OL.40.005451, 10.1364/OL.41.002270, 10.1364/OL.41.004811, 10.1364/PRJ.6.000756, 10.1038/lsa.2016.259, 10.1103/PhysRevApplied.16.034001, 10.1038/s41566-020-00750-2, 10.1117/1.3565046, 10.1038/s41598-020-67141-z, 10.1038/s41598-020-70783-8, 10.1364/OL.447853, 10.1109/LPT.2020.3011673, 10.1016/j.optcom.2021.127783, 10.1364/OE.451292, 10.3390/cryst10090835, 10.1364/OL.23.000992, 10.1038/s41598-022-18530-z, 10.1088/1464-4258/11/1/015507, 10.1016/j.optlastec.2022.108881, '},
#  {'title': 'An ontology-based secure design framework for graph-based databases',
#   'keywords': '',
#   'abstract': 'Graph-based databases are concerned with performance and flexibility. Most of the existing approaches used to design secure NoSQL databases are limited to the final implementation stage, and do not involve the design of security and access control issues at higher abstraction levels. Ensuring security and access control for Graph-based databases is difficult, as each approach differs significantly depending on the technology employed. In this paper, we propose the first technology-ascetic framework with which to design secure Graph-based databases. Our proposal raises the abstraction level by using ontologies to simultaneously model database and security requirements together. This is supported by the TITAN framework, which facilitates the way in which both aspects are dealt with. The great advantages of our approach are, therefore, that it: allows database designers to focus on the simultaneous protection of security and data while ignoring the implementation details; facilitates the secure design and rapid migration of security rules by deriving specific security measures for each underlying technology, and enables database designers to employ ontology reasoning in order to verify whether the security rules are consistent. We show the applicability of our proposal by applying it to a case study based on a hospital data access control.',
#   'date': '01/03/2024',
#   'authors': 'CARLOS BLANCO BUENO;',
#   'doi': '10.1016/j.csi.2023.103801',
#   'field': 'Law,Hardware and Architecture,Software,General Computer Science,Computer Science Applications',
#   'references': '10.1016/j.telpol.2014.10.002, 10.1145/2699026.2699136, 10.3389/fdata.2019.00001, 10.1016/j.knosys.2021.107489, 10.1016/j.eswa.2018.08.026, 10.1006/knac.1993.1008, 10.1007/s10270-015-0486-9, 10.24297/ijct.v16i7.6467, 10.1007/978-3-319-25264-3_35, 10.1007/s10115-021-01589-x, 10.1142/S219688882150024X, 10.3390/electronics10212616, 10.1109/ACCESS.2021.3104293, 10.1162/dint_a_00029, 10.1088/1742-6596/1818/1/012211, '},
#  {'title': 'Computation of parabolic cylinder functions having complex argument',
#   'keywords': '',
#   'abstract': 'Numerical methods for the computation of the parabolic cylinder function U(a,z) for real a and complex z are presented. The main tools are recent asymptotic expansions involving exponential and Airy functions, with slowly varying analytic coefficient functions involving simple coefficients, and stable integral representations; these two main methods can be complemented with Maclaurin series and a Poincaré asymptotic expansion. We provide numerical evidence showing that the combination of these methods is enough for computing the function with 5 × 10-13 relative accuracy in double precision floating point arithmetic.',
# %%
df = pd.DataFrame(new_rows)
df.to_csv('outputRepositori.csv', index=False, header=True,  encoding="utf-8")

# %% [markdown]
# ----
# ### <a name="queries">Use of DSpace</a>
# To interact with DSpace, we need several steps, next :
#   1. retrieve the <span style="color:red">communities</span> of the repository :
#     - to the REST URL, add **communities/** : Return an list of all communities of the repository in JSON

# %%
#  REST API URL to search documents in the 
base_url = "https://repositorio.unican.es/rest/"

# %%
# GET request
get_communities = requests.get(base_url + "communities/")

# %%
print("response from "+base_url + "communities/")
print(get_communities.content)
data = get_communities.json()
# Out:
# response from https://repositorio.unican.es/rest/communities/
# b'[{"uuid":"2e6ca748-8c15-41cc-88ed-233f92787953","name":"Centro Internacional de Estudios Superiores del Espa\xc3\xb1ol CIESE-Comillas (Centro adscrito)","handle":"10902/6182","type":"community","expand":["parentCommunity","collections","subCommunities","logo","all"],"logo":null,"parentCommunity":null,"copyrightText":"","introductoryText":"","shortDescription":"","sidebarText":"","countItems":160,"collections":[],"link":"/rest/communities/2e6ca748-8c15-41cc-88ed-233f92787953","subcommunities":[]},{"uuid":"7508978b-1eda-4fc8-8529-4bf3d930d494","name":"Departamento de Administraci\xc3\xb3n de Empresas","handle":"10902/17","type":"community","expand":["parentCommunity","collections","subCommunities","logo","all"],"logo":null,"parentCommunity":null,"copyrightText":"","introductoryText":"El Departamento de Administraci\xc3\xb3n de Empresas centra su actividad docente e investigadora en el \xc3\xa1mbito de la gesti\xc3\xb3n de empresas e instituciones, abarcando todas las \xc3\xa1reas funcionales participan en la administraci\xc3\xb3n de las organizaciones. En la actualidad, el Departamento est\xc3\xa1 formado por 101 docentes encuadrados en 3 \xc3\x81reas de Conocimiento: Organizaci\xc3\xb3n de Empresas, Econom\xc3\xada Financiera y Contabilidad, y Comercializaci\xc3\xb3n e Investigaci\xc3\xb3n de Mercados.","shortDescription":"","sidebarText":"","countItems":585,"collections":[],"link":"/rest/communities/7508978b-1eda-4fc8-8529-4bf3d930d494","subcommunities":[]},{"uuid":"feeb4485-48d6-44c0-a0f1-0e387b719f86","name":"Departamento de Anatom\xc3\xada y Biolog\xc3\xada Celular","handle":"10902/18","type":"community","expand":["parentCommunity","collections","subCommunities","logo","all"],"logo":null,"parentCommunity":null,"copyrightText":"","introductoryText":"","shortDescription":"","sidebarText":"","countItems":122,"collections":[],"link":"/rest/communities/feeb4485-48d6-44c0-a0f1-0e387b719f86","subcommunities":[]},{"uuid":"ab1d9d49-08a1-4ae1-b3bc-f5c72d161fc1","name":"Departamento de Biolog\xc3\xada Molecular","handle":"10902/19","type":"community","expand":["parentCommunity","collections","subCommunities","logo","all"],"logo":null,"parentCommunity":null,"copyrightText":"","introductoryText":"","shortDescription":"","sidebarText":"","countItems":449,"collections":[],"link":"/rest/communities/ab1d9d49-08a1-

#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 449,
#   'collections': [],
#   'link': '/rest/communities/ab1d9d49-08a1-4ae1-b3bc-f5c72d161fc1',
#   'subcommunities': []},
#  {'uuid': '1eb14ecd-a848-4697-89a4-0beb2029eed8',
#   'name': 'Departamento de Ciencia e Ingeniería del Terreno y de los Materiales',
#   'handle': '10902/20',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': 'La investigación del departamento se concentra en torno a sus grupos de investigación:\r\n\r\nGRUPO DE MATERIALES - LADICIM;\r\n\r\nGRUPO DE GEOTECNIA;  \r\n\r\nGRUPO DE GEOLOGÍA APLICADA;  \r\n\r\nGRUPO DE CORROSIÓN',
#   'shortDescription': '',
#   'sidebarText': 'E.T.S. Ingenieros de Caminos, Canales y Puertos  \r\nAvda. de los Castros s/n  \r\n39005 SANTANDER (CANTABRIA)  \r\nESPAÑA',
#   'countItems': 378,
#   'collections': [],
#   'link': '/rest/communities/1eb14ecd-a848-4697-89a4-0beb2029eed8',
#   'subcommunities': []},
#  {'uuid': '15f461a0-0b14-41f3-983e-29bfea027b5d',
#   'name': 'Departamento de Ciencias de la Tierra y Física de la Materia Condensada',
#   'handle': '10902/21',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 274,
#   'collections': [],
#   'link': '/rest/communities/15f461a0-0b14-41f3-983e-29bfea027b5d',
#   'subcommunities': []},
#  {'uuid': 'fd84e407-af41-460c-ac53-f0c2c1190275',
#   'name': 'Departamento de Ciencias Históricas',
#   'handle': '10902/22',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 390,
#   'collections': [],
#   'link': '/rest/communities/fd84e407-af41-460c-ac53-f0c2c1190275',
#   'subcommunities': []},
#  {'uuid': 'e701bde5-6116-4918-9cf2-379479795288',
#   'name': 'Departamento de Ciencias Médicas y Quirúrgicas',
#   'handle': '10902/23',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 632,
#   'collections': [],
#   'link': '/rest/communities/e701bde5-6116-4918-9cf2-379479795288',
#   'subcommunities': []},
#  {'uuid': '70ee73eb-54d5-48c8-8fdf-f47d60682840',
#   'name': 'Departamento de Ciencias y Técnicas de la Navegación y de la Construcción Naval',
#   'handle': '10902/24',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 86,
#   'collections': [],
#   'link': '/rest/communities/70ee73eb-54d5-48c8-8fdf-f47d60682840',
#   'subcommunities': []},
#  {'uuid': '64dfa1f0-2b93-4924-8750-f221ba6c2311',
#   'name': 'Departamento de Ciencias y Técnicas del Agua y del Medio Ambiente',
#   'handle': '10902/25',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 389,
#   'collections': [],
#   'link': '/rest/communities/64dfa1f0-2b93-4924-8750-f221ba6c2311',
#   'subcommunities': []},
#  {'uuid': 'd056e08e-397c-4bf1-b5f9-f5429421e587',
#   'name': 'Departamento de Derecho Privado',
#   'handle': '10902/26',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 305,
#   'collections': [],
#   'link': '/rest/communities/d056e08e-397c-4bf1-b5f9-f5429421e587',
#   'subcommunities': []},
#  {'uuid': '54bd01bd-57f0-4739-b5d5-0292b3379ca7',
#   'name': 'Departamento de Derecho Público',
#   'handle': '10902/27',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 372,
#   'collections': [],
#   'link': '/rest/communities/54bd01bd-57f0-4739-b5d5-0292b3379ca7',
#   'subcommunities': []},
#  {'uuid': 'f587b4ee-6db3-4f7e-9fba-26f072b2ea6c',
#   'name': 'Departamento de Economía',
#   'handle': '10902/29',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems':

#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 199,
#   'collections': [],
#   'link': '/rest/communities/816f4d75-74a2-4e31-9d16-837495815bb1',
#   'subcommunities': []},
#  {'uuid': 'ad4afa0a-8ae6-42c5-9993-9eabccbe5327',
#   'name': 'Departamento de Ingeniería Estructural y Mecánica',
#   'handle': '10902/40',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 154,
#   'collections': [],
#   'link': '/rest/communities/ad4afa0a-8ae6-42c5-9993-9eabccbe5327',
#   'subcommunities': []},
#  {'uuid': 'bf60bfc4-a22e-42e9-9709-618a96ba6787',
#   'name': 'Departamento de Ingeniería Geográfica y Técnicas de Expresión Gráfica',
#   'handle': '10902/41',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 93,
#   'collections': [],
#   'link': '/rest/communities/bf60bfc4-a22e-42e9-9709-618a96ba6787',
#   'subcommunities': []},
#  {'uuid': 'c11e342c-e4c0-47c7-8b2f-49f57f20a857',
#   'name': 'Departamento de Ingeniería Informática y Electrónica',
#   'handle': '10902/30',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': 'Este departamento se denominó Departamento de Electrónica y Computadores hasta 2014',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 163,
#   'collections': [],
#   'link': '/rest/communities/c11e342c-e4c0-47c7-8b2f-49f57f20a857',
#   'subcommunities': []},
#  {'uuid': 'dfff8b20-a834-4568-b9a8-c71e6d40fc67',
#   'name': 'Departamento de Ingenierías Química y Biomolecular',
#   'handle': '10902/42',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': 'Este departamento se denominó Departamento de Ingeniería Química y Química Inorgánica hasta el 24/09/2013',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 605,
#   'collections': [],
#   'link': '/rest/communities/dfff8b20-a834-4568-b9a8-c71e6d40fc67',
#   'subcommunities': []},
#  {'uuid': '9ead14f9-a142-48c5-8ee8-d0448574e493',
#   'name': 'Departamento de Matemática Aplicada y Ciencias de la Computación',
#   'handle': '10902/43',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 494,
#   'collections': [],
#   'link': '/rest/communities/9ead14f9-a142-48c5-8ee8-d0448574e493',
#   'subcommunities': []},
#  {'uuid': '92aaba72-8d31-41ca-a1b9-0e6df50b759b',
#   'name': 'Departamento de Matemáticas, Estadística y Computación',
#   'handle': '10902/44',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 373,
#   'collections': [],
#   'link': '/rest/communities/92aaba72-8d31-41ca-a1b9-0e6df50b759b',
#   'subcommunities': []},
#  {'uuid': '583c7be0-3769-4cd1-8457-3e8580ae1936',
#   'name': 'Departamento de Medicina y Psiquiatría',
#   'handle': '10902/45',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 909,
#   'collections': [],
#   'link': '/rest/communities/583c7be0-3769-4cd1-8457-3e8580ae1936',
#   'subcommunities': []},
#  {'uuid': '5b8dfec4-a2fc-43b4-ba66-957ae027af6d',
#   'name': 'Departamento de Química e Ingeniería de Procesos y Recursos',
#   'handle': '10902/3576',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 152,
#   'collections': [],
#   'link': '/rest/communities/5b8dfec4-a2fc-43b4-ba66-957ae027af6d',
#   'subcommunities': []},
#  {'uuid': '763d55a0-4758-4040-b015-f334a88008e4',
#   'name': 'Departamento de Tecnología Electrónica e Ing. Sistemas y Automática (TEISA)',
#   'handle': '10902/46',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 805,
#   'collections': [],
#   'link': '/rest/communities/763d55a0-4758-4040-b015-f334a88008e4',
#   'subcommunities': []},
#  {'uuid': 'dca54c2e-e4e2-474e-8085-f7325890cd92',
#   'name': 'Departamento de Transportes y Tecnología de Proyectos y Procesos',
#   'handle': '10902/47',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems':

#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 1134,
#   'collections': [],
#   'link': '/rest/communities/708c8f00-d886-41f6-a23a-cb652bea6e64',
#   'subcommunities': []},
#  {'uuid': 'cafbdc47-99d8-4faa-9b45-171b2d6fa509',
#   'name': 'Facultad de Educación',
#   'handle': '10902/75',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 2227,
#   'collections': [],
#   'link': '/rest/communities/cafbdc47-99d8-4faa-9b45-171b2d6fa509',
#   'subcommunities': []},
#  {'uuid': 'deb18fce-ee46-4a55-a257-73516ea43914',
#   'name': 'Facultad de Enfermería',
#   'handle': '10902/70',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 1212,
#   'collections': [],
#   'link': '/rest/communities/deb18fce-ee46-4a55-a257-73516ea43914',
#   'subcommunities': []},
#  {'uuid': '8152295f-d455-4bd6-9ec0-eba1e31da2fe',
#   'name': 'Facultad de Filosofía y Letras',
#   'handle': '10902/76',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 892,
#   'collections': [],
#   'link': '/rest/communities/8152295f-d455-4bd6-9ec0-eba1e31da2fe',
#   'subcommunities': []},
#  {'uuid': '8141b115-736a-4906-99cc-4f1f0568b4a2',
#   'name': 'Facultad de Medicina',
#   'handle': '10902/77',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 1219,
#   'collections': [],
#   'link': '/rest/communities/8141b115-736a-4906-99cc-4f1f0568b4a2',
#   'subcommunities': []},
#  {'uuid': '88e3bb19-d039-4555-a12f-d16ea4b08ab1',
#   'name': 'Grado de Ingeniería Civil',
#   'handle': '10902/78',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 476,
#   'collections': [],
#   'link': '/rest/communities/88e3bb19-d039-4555-a12f-d16ea4b08ab1',
#   'subcommunities': []},
#  {'uuid': '800a71d2-58e6-4b9c-bb1d-e3f4ee41f1fd',
#   'name': 'Grado en Administración y Dirección de Empresas',
#   'handle': '10902/213',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 1301,
#   'collections': [],
#   'link': '/rest/communities/800a71d2-58e6-4b9c-bb1d-e3f4ee41f1fd',
#   'subcommunities': []},
#  {'uuid': '2d4f2225-23f9-4cdc-9914-f3c4de21d24b',
#   'name': 'Grado en Derecho',
#   'handle': '10902/219',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 692,
#   'collections': [],
#   'link': '/rest/communities/2d4f2225-23f9-4cdc-9914-f3c4de21d24b',
#   'subcommunities': []},
#  {'uuid': '7b9b3cd9-9235-423d-a87a-e38ec92fdc2d',
#   'name': 'Grado en Economía',
#   'handle': '10902/214',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 483,
#   'collections': [],
#   'link': '/rest/communities/7b9b3cd9-9235-423d-a87a-e38ec92fdc2d',
#   'subcommunities': []},
#  {'uuid': '5399967f-a17e-402f-848d-6842054d7915',
#   'name': 'Grado en Enfermería',
#   'handle': '10902/201',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 903,
#   'collections': [],
#   'link': '/rest/communities/5399967f-a17e-402f-848d-6842054d7915',
#   'subcommunities': []},
#  {'uuid': 'b983fc77-4e14-4106-880d-15753f9fdb64',
#   'name': 'Grado en Estudios Hispánicos',
#   'handle': '10902/6183',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 39,
#   'collections': [],
#   'link': '/rest/communities/b983fc77-4e14-4106-880d-15753f9fdb64',
#   'subcommunities': []},
#  {'uuid': '3930a2f3-cc25-415d-8780-72e125288998',
#   'name': 'Grado en Física',
#   'handle': '10902/205',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 300,
#   'collections': [],
#   'link': '/rest/communities/3930a2f3-cc25-415d-8780-72e125288998',
#   'subcommunities': []},
#  {'uuid': 'f6fa0281-5768-4da4-ad29-53368afec161',
#   'name': 'Grado en Fisioterapia',
#   'handle': '10902/4514',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 200,
#   'collections': [],
#   'link': '/rest/communities/f6fa0281-5768-4da4-ad29-53368afec161',
#   'subcommunities': []},
#  {'uuid': '933f6eca-da16-4919-8e6a-93bb167360dd',
#   'name': 'Grado en Geografía y Ordenación del Territorio',
#   'handle': '10902/227',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 110,
#   'collections': [],
#   'link': '/rest/communities/933f6eca-da16-4919-8e6a-93bb167360dd',
#   'subcommunities': []},
#  {'uuid': '04e06d9f-4ee1-4b89-a446-67531485d72e',
#   'name': 'Grado en Gestión Hotelera y Turística',
#   'handle': '10902/21131',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 102,
#   'collections': [],
#   'link': '/rest/communities/04e06d9f-4ee1-4b89-a446-67531485d72e',
#   'subcommunities': []},
#  {'uuid': '95b2d8aa-2bef-46c9-a344-3e26e5186556',
#   'name': 'Grado en Historia',
#   'handle': '10902/226',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 326,
#   'collections': [],
#   'link': '/rest/communities/95b2d8aa-2bef-46c9-a344-3e26e5186556',
#   'subcommunities': []},
#  {'uuid': '80604d13-b0a9-459f-bb6d-a25497efa6af',
#   'name': 'Grado en Ingeniería Civil con Mención en Construcciones Civiles (Plan 2020)',
#   'handle': '10902/19050',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 30,
#   'collections': [],
#   'link': '/rest/communities/80604d13-b0a9-459f-bb6d-a25497efa6af',
#   'subcommunities': []},
#  {'uuid': 'd6eda7b6-a55c-400a-8165-b1bea003877a',
#   'name': 'Grado en Ingeniería de los Recursos Energéticos',
#   'handle': '10902/203',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 171,
#   'collections': [],
#   'link': '/rest/communities/d6eda7b6-a55c-400a-8165-b1bea003877a',
#   'subcommunities': []},
#  {'uuid': '0f5aaae8-3f0a-4142-b516-714dc12f6ce1',
#   'name': 'Grado en Ingeniería de los Recursos Mineros',
#   'handle': '10902/204',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 147,
#   'collections': [],
#   'link': '/rest/communities/0f5aaae8-3f0a-4142-b516-714dc12f6ce1',
#   'subcommunities': []},
#  {'uuid': 'b9aa9222-5184-4df1-a10b-2552542540bc',
#   'name': 'Grado en Ingeniería de Tecnologías de Telecomunicación',
#   'handle': '10902/188',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 530,
#   'collections': [],
#   'link': '/rest/communities/b9aa9222-5184-4df1-a10b-2552542540bc',
#   'subcommunities': []},
#  {'uuid': '0e2db916-0532-415d-9e58-0f8e92681fb7',
#   'name': 'Grado en Ingeniería Eléctrica',
#   'handle': '10902/189',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 177,
#   'collections': [],
#   'link': '/rest/communities/0e2db916-0532-415d-9e58-0f8e92681fb7',
#   'subcommunities': []},
#  {'uuid': 'a3725d9e-3f16-4c3d-b42a-7806cc9117b7',
#   'name': 'Grado en Ingeniería en Electrónica Industrial y Automática',
#   'handle': '10902/190',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 211,
#   'collections': [],
#   'link': '/rest/communities/a3725d9e-3f16-4c3d-b42a-7806cc9117b7',
#   'subcommunities': []},
#  {'uuid': '21b80d37-74eb-4755-955a-0aaf0205baa3',
#   'name': 'Grado en Ingeniería en Tecnologías Industriales',
#   'handle': '10902/191',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems':

#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 976,
#   'collections': [],
#   'link': '/rest/communities/2b30799b-0b4a-46b5-8216-cda1d35b1836',
#   'subcommunities': []},
#  {'uuid': '44f22e72-2ce4-4a34-b6d6-90d2ac0bd65c',
#   'name': 'Grado en Relaciones Laborales',
#   'handle': '10902/220',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 272,
#   'collections': [],
#   'link': '/rest/communities/44f22e72-2ce4-4a34-b6d6-90d2ac0bd65c',
#   'subcommunities': []},
#  {'uuid': 'd73b4d4d-41a1-4d0b-9d7e-58bae41b72e9',
#   'name': 'Grado en Turismo',
#   'handle': '10902/4519',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 205,
#   'collections': [],
#   'link': '/rest/communities/d73b4d4d-41a1-4d0b-9d7e-58bae41b72e9',
#   'subcommunities': []},
#  {'uuid': 'c44f6123-a56a-474b-9472-1bacea886559',
#   'name': 'Ingeniería de Caminos, Canales y Puertos',
#   'handle': '10902/161',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 65,
#   'collections': [],
#   'link': '/rest/communities/c44f6123-a56a-474b-9472-1bacea886559',
#   'subcommunities': []},
#  {'uuid': '81f26eca-412a-4d35-9c63-c3e37b55dfcc',
#   'name': 'Ingeniería de Telecomunicación',
#   'handle': '10902/336',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 308,
#   'collections': [],
#   'link': '/rest/communities/81f26eca-412a-4d35-9c63-c3e37b55dfcc',
#   'subcommunities': []},
#  {'uuid': '5385a332-c8ad-478e-9023-346d4fffceae',
#   'name': 'Ingeniería Industrial',
#   'handle': '10902/335',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 277,
#   'collections': [],
#   'link': '/rest/communities/5385a332-c8ad-478e-9023-346d4fffceae',
#   'subcommunities': []},
#  {'uuid': 'de61378d-287c-47c1-8a3b-f4688abe718d',
#   'name': 'Ingeniería Informática',
#   'handle': '10902/397',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 99,
#   'collections': [],
#   'link': '/rest/communities/de61378d-287c-47c1-8a3b-f4688abe718d',
#   'subcommunities': []},
#  {'uuid': 'b1f90bb4-6efa-4b31-a287-7e00d6662fd9',
#   'name': 'Ingeniería Química',
#   'handle': '10902/334',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 146,
#   'collections': [],
#   'link': '/rest/communities/b1f90bb4-6efa-4b31-a287-7e00d6662fd9',
#   'subcommunities': []},
#  {'uuid': '3ff7e8e5-e433-453b-884b-519e4ae63acb',
#   'name': 'Ingeniería Técnica de Obras públicas',
#   'handle': '10902/164',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 12,
#   'collections': [],
#   'link': '/rest/communities/3ff7e8e5-e433-453b-884b-519e4ae63acb',
#   'subcommunities': []},
#  {'uuid': '7abe691e-1281-4aef-8ceb-6d862f9c5587',
#   'name': 'Ingeniería técnica de Telecomunicación',
#   'handle': '10902/327',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 170,
#   'collections': [],
#   'link': '/rest/communities/7abe691e-1281-4aef-8ceb-6d862f9c5587',
#   'subcommunities': []},
#  {'uuid': 'd274a03a-98b4-470b-a091-8cc61e8561fe',
#   'name': 'Ingeniería Técnica Industrial. Especialidad en Electricidad',
#   'handle': '10902/332',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 75,
#   'collections': [],
#   'link': '/rest/communities/d274a03a-98b4-470b-a091-8cc61e8561fe',
#   'subcommunities': []},
#  {'uuid': 'e1c2f802-9d1b-4075-a6db-4af48f46d6c5',
#   'name': 'Ingeniería Técnica Industrial. Especialidad en Electrónica Industrial',
#   'handle': '10902/333',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 108,
#   'collections': [],
#   'link': '/rest/communities/e1c2f802-9d1b-4075-a6db-4af48f46d6c5',
#   'subcommunities': []},
#  {'uuid': '03601811-8e61-4a61-a4e7-0996ffe5f5d4',
#   'name': 'Ingeniería Técnica Industrial. Especialidad en Mecánica',
#   'handle': '10902/329',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 230,
#   'collections': [],
#   'link': '/rest/communities/03601811-8e61-4a61-a4e7-0996ffe5f5d4',
#   'subcommunities': []},
#  {'uuid': '6e8f0e26-6e2d-44f9-9ed4-fc7012e0ab4a',
#   'name': 'Ingeniería Técnica Industrial. Especialidad en Química Industrial',
#   'handle': '10902/331',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 157,
#   'collections': [],
#   'link': '/rest/communities/6e8f0e26-6e2d-44f9-9ed4-fc7012e0ab4a',
#   'subcommunities': []},
#  {'uuid': 'b1e676b3-0545-4e3e-a48c-c0c8d233574c',
#   'name': 'Ingeniería Técnica Naval. Especialidad en Propulsión y Servicios del Buque',
#   'handle': '10902/398',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 70,
#   'collections': [],
#   'link': '/rest/communities/b1e676b3-0545-4e3e-a48c-c0c8d233574c',
#   'subcommunities': []},
#  {'uuid': '82297fd1-7335-4f71-96c4-207d42cfdc72',
#   'name': 'Instituto de Biomedicina y Biotecnología de Cantabria (IBBTEC)',
#   'handle': '10902/51',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 156,
#   'collections': [],
#   'link': '/rest/communities/82297fd1-7335-4f71-96c4-207d42cfdc72',
#   'subcommunities': []},
#  {'uuid': 'b17552cf-d4d6-4e6e-9c18-3b490985d544',
#   'name': 'Instituto de Física de Cantabria\xa0(IFCA) - centro mixto UC-CSIC',
#   'handle': '10902/48',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 1197,
#   'collections': [],
#   'link': '/rest/communities/b17552cf-d4d6-4e6e-9c18-3b490985d544',
#   'subcommunities': []},
#  {'uuid': '8d934bb7-097d-479c-9705-54f206d7d868',
#   'name': "Instituto de Hidráulica Ambiental de Cantabria 'IH Cantabria'",
#   'handle': '10902/50',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 361,
#   'collections': [],
#   'link': '/rest/communities/8d934bb7-097d-479c-9705-54f206d7d868',
#   'subcommunities': []},
#  {'uuid': '3c6e5101-25a8-424d-b258-13d654d29745',
#   'name': 'Instituto de Investigación Marqués de Valdecilla (IDIVAL)',
#   'handle': '10902/13739',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': 'Gracias al impulso de sus Instituciones fundadoras, Gobierno de Cantabria y Universidad de Cantabria (UC), el Instituto de Investigación Marqués de Valdecilla (IDIVAL) promueve y desarrolla la investigación y la innovación en el entorno biosanitario de Cantabria que tiene como epicentro al Hospital Universitario Marqués de Valdecilla (HUMV), con vocación de buscar soluciones a los problemas de salud y contribuir al desarrollo científico, docente, social y económico del entorno al que el IDIVAL pertenece y se debe.',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 710,
#   'collections': [],
#   'link': '/rest/communities/3c6e5101-25a8-424d-b258-13d654d29745',
#   'subcommunities': []},
#  {'uuid': 'ee69d47a-9567-4839-9d0a-7eb30a3c4f8f',
#   'name': 'Instituto Internacional de Investigaciones Prehistóricas de Cantabria\xa0(IIIPC)',
#   'handle': '10902/49',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 170,
#   'collections': [],
#   'link': '/rest/communities/ee69d47a-9567-4839-9d0a-7eb30a3c4f8f',
#   'subcommunities': []},
#  {'uuid': '9eb62ae6-e41f-4f4f-a691-9d9cb6468163',
#   'name': 'Licenciatura en Física',
#   'handle': '10902/395',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 29,
#   'collections': [],
#   'link': '/rest/communities/9eb62ae6-e41f-4f4f-a691-9d9cb6468163',
#   'subcommunities': []},
#  {'uuid': 'a8e020af-9fef-4aca-b4ae-2782bcb1e594',
#   'name': 'Licenciatura en Matemáticas',
#   'handle': '10902/396',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 9,
#   'collections': [],
#   'link': '/rest/communities/a8e020af-9fef-4aca-b4ae-2782bcb1e594',
#   'subcommunities': []},
#  {'uuid': '7954a4d6-289e-4d85-9e77-6e3cfc99fdf9',
#   'name': 'Máster Conjunto Erasmus Mundus en Diseño, Construcción y Gestión Sostenible del Entorno Construido',
#   'handle': '10902/31047',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 0,
#   'collections': [],
#   'link': '/rest/communities/7954a4d6-289e-4d85-9e77-6e3cfc99fdf9',
#   'subcommunities': []},
#  {'uuid': 'c5a92d28-2816-411b-ab64-227c6eb67cc0',
#   'name': 'Máster en Investigación, Tecnología y Gestión de la Construcción en Europa',
#   'handle': '10902/165',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': 'Hasta el curso 2015/16 se denominó "Máster  europeo en Ingeniería de la Construcción"',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 42,
#   'collections': [],
#   'link': '/rest/communities/c5a92d28-2816-411b-ab64-227c6eb67cc0',
#   'subcommunities': []},
#  {'uuid': '393e28fe-1faa-45ce-be60-39d127605aa4',
#   'name': 'Máster Universitario Del Mediterráneo al Atlántico: La Construcción de Europa entre el Mundo Antiguo y Medieval',
#   'handle': '10902/228',
#   'type': 'community',
#   'expand': ['parentCommunity',
#    'collections',
#    'subCommunities',
#    'logo',
#    'all'],
#   'logo': None,
#   'parentCommunity': None,
#   'copyrightText': '',
#   'introductoryText': '',
#   'shortDescription': '',
#   'sidebarText': '',
#   'countItems': 42,
#   'collections': [],
#   'link': '/rest/communities/393e28fe-1faa-45ce-be60-39d127605aa4',
#   'subcommunities': []}]

# %% [markdown]
# ### Find the best communities
#   2. **identify** the <span style="color:red">communities</span>
#    - if the id of the communities you search are unknown, you have to browse the results...
#
#    Ex. find a communities about computer science articles :

# %%
def find_id(data, term):
    """from dictionary of data having name and ifd fields, 
       search if the term is in the name and 
       return the list of id"""
    id_list = []
    for community in data:
        if community['name'].find(term)>-1:
            id_list.append(community['uuid'])
    return id_list

# %%
#the name to search is "Computación", you have to know that it's this name to find !!
id_communities = find_id(data, "Computación")
print(id_communities)
# Out:
# ['9ead14f9-a142-48c5-8ee8-d0448574e493', '92aaba72-8d31-41ca-a1b9-0e6df50b759b']

# %% [markdown]
# ### Find the collectionS
#   3. retrieve the <span style="color:red">**collections**</span> (list of articles, books, patents, thesis, ...)
#     - to the REST URL, add **communities/[id of the selected community]/collections** : Return an list of all the collections for the community, in JSON

# %%
# GET request for the 2nd community (for example)
address = base_url + "communities/" + id_communities[1] + "/collections"
get_collections = requests.get(address )

# %%
print("response from "+address)
data = get_collections.json()
for d in data: print(d['name'])
# Out:
# response from https://repositorio.unican.es/rest/communities/92aaba72-8d31-41ca-a1b9-0e6df50b759b/collections
# D21 Artículos
# D21 Congresos
# D21 Documentos de trabajo
# D21 Libros y partes de libros
# D21 Patentes
# D21 Proyectos de Investigación
# D21 Tesis

# %% [markdown]
# ### get the collection
#   4. **identify** the <span style="color:red">collection id</span>
#    - if the id of the collections you search are unknown, you have to browse the results...
#
#    Ex. find a collection about articles :

# %%
#the name to search to get articles is "Artículos"
id_collections = find_id(data, "Artículos")
print(id_collections)
# Out:
# ['f8ba545d-52f6-415d-9211-2b9a1b974a18']

# %% [markdown]
# ### Find the articles
#   5. retrieve the <span style="color:red">**articles**</span> from a collection of a community<br>
#     - to the REST URL, add **collections/[id of the selected collection]/items** : Return an list of all the items for the collection, in JSON

# %%
# GET request for the articles of the collection
address = base_url + "collections/" + id_collections[0] + "/items"
get_collections = requests.get(address )

# %%
print("response from "+address)
data = get_collections.json()
for d in data: print(d['name'])
# Out:
# response from https://repositorio.unican.es/rest/collections/f8ba545d-52f6-415d-9211-2b9a1b974a18/items
# Sobre un contraejemplo a la conjetura de Hirsch
# The Covering Radius and a Discrete Surface Area for Non-Hollow Simplices
# Simplified procedure for efficient and unbiased population size estimation
# XLVIII Olimpiada Matemática Española, Santander, 22 al 25 de marzo de 2012
# A unified approach towards the impossibility of finite time vanishing depth for incompressible free boundary flows
# Blowups with log canonical singularities
# Union bound minimization approach for designing grassmannian constellations
# Some issues on the automatic computation of plane envelopes in interactive environments
# A Framework for Identifying Sequences of Interactions That Cause Usability Problems in Collaborative Systems
# Models for the Assessment of Treatment Improvement: The Ideal and the Feasible
# El problema de la galería de arte: elaboración de conjeturas y demostraciones con GeoGebra
# Análisis epistémico y cognitivo de una tarea de visualización en el espacio bidimensional
# Planck 2013 results. III. LFI systematic uncertainties
# Aspectos computacionales de la Descomposición Primaria
# Hypercyclicity for the Elements of the Commutant of an Operator
# Global existence and decay of the inhomogeneous Muskat problem with Lipschitz initial data
# Computing the Kummer function U(a, b, z) for small values of the arguments
# Evaluating the pharmacological response in fluorescence microscopy images: The Δm algorithm
# Unilateral problems for the p-Laplace operator in perforated media involving large parameters
# On ℓ∞- Grothendieck subspaces
# Planck 2013 results. II. Low Frequency Instrument data processing
# The Cayley Trick, lifting subdivisions and the Bohne-Dress theorem on zonotopal tilings
# On the Unavoidable Uncertainty of Truth in Dynamic Geometry Proving
# The F-actin cortical network is a major factor influencing the organization of the secretory machinery in chromaffin cells
# Recovering zeros of polynomials modulo a prime
# On a thin film model with insoluble surfactant
# Classification of Alzheimer's patients through ubiquitous computing
# Convexity properties of the condition number
# Hyperquadratic power series in F3((T−1)) with partial quotients of degree 1
# Unimodular covers of 3-dimensional parallelepipeds and Cayley sums
# Local duality for Banach spaces
# A propósito de la envolvente de una familia de elipses
# The finiteness threshold width of lattice polytopes
# Carleman type inequalities for fractional relativistic operators
# The Average Condition Number of Most Tensor Rank Decomposition Problems is Infinite
# Classes of operators preserved by extensions or liftings
# Reconstructing points of superelliptic curves over a prime finite field
# Robust multiobjective optimisation for fuzzy job shop problems
# Cotauberian Operators on L1(0, 1) Obtained by Lifting
# Superprojective Banach spaces
# Global solutions for a supercritical drift-diffusion equation
# Predictors of positive (18) F-FDG PET/CT-scan for large vessel vasculitis in patients with persistent polymyalgia rheumatica
# Supervised Classification of Healthcare Text Data Based on Context-Defined Categories
# A Convolutional Neural Network-Based Method for Human Movement Patterns Classification in Alzheimer?s Disease
# Similarity of samples and trimming
# Convolution operators on group algebras which are tauberian or cotauberian
# On the minimum value of the condition number of polynomials
# Efficient and Unbiased Estimation of Population Size
# Evaluación de un modelo de creencias transcultural para el aprendizaje de las matemáticas
# Conceptualizing and Describing Teachers´ Learning of Pedagogical Concepts
# A machine learning approach to detect Parkinson's disease by looking at gait alterations
# Caminos de aprendizaje en la formación de profesores de matemáticas: objetivos, tareas y evaluación
# Computing envelopes in dynamic geometry environments
# Towards automatic evaluation of the Quality-in-Use in context-aware software systems
# Recent software developments for special functions in the Santander–Amsterdam project
# The CountEm software: simple, efficient and unbiased population size estimation
# On irreducible divisors of iterated polynomials
# Simplified error bounds for turning point expansions
# Ultraquadrics associated to affine and projective automorphisms
# Efficient algorithms for the inversion of the cumulative central beta distribution
# A Method to automate the prediction of student academic performance from early stages of the course
# Grothendieck spaces: the landscape and perspectives
# A canonical form for the continuous piecewise polynomial functions
# Using implicit equations of parametric curves and surfaces without computing them: Polynomial algebra by values
# Efficient computation of Laguerre polynomials
# Bar-and-joint rigidity on the moment curve coincides with cofactor rigidity on a conic
# Successive magnetic transitions in TbNiAl2 studied by neutron diffraction
# Feuerbach: superación de la religión como forma de autoconciencia humana
# Using cmb polarization to constrain the anomalous nature of the cold spot with an incomplete-sky coverage
# On a nonlocal differential equation describing roots of polynomials under differentiation
# Factoring analytic multivariate polynomials and non-standard Cauchy–Riemann conditions
# Conceptual Model-Based Approach to Teaching Multiplication and Division Word-Problem Solving to A Student with Autism Spectrum Disorder
# Reliable Computation of the Zeros of Solutions of Second Order Linear ODEs Using a Fourth Order Method
# Monotonicity properties and bounds for the chi-squareand gamma distributions.
# Estrategias y representaciones en la resolución de problemas aritméticos de división en estudiantes con trastorno del espectro autista: un estudio de caso
# Usos del error en la enseñanza de las matemáticas
# On the shape of curves that are rational in polar coordinates
# Automatic Deduction in (Dynamic) Geometry: Loci Computation
# On a generalized doubly parabolic Keller-Segel system in one spatial dimension
# Surface tension stabilization of the Rayleigh-Taylor instability for a fluid layer in a porous medium
# Growth in the Muskat problem
# Benchmarks for fuzzy job shop problems
# Classification of Almost Norden Golden Manifolds
# Remark on Justification of Asymptotics of Spectra of Cylindrical Waveguides with Periodic Singular Perturbations of Boundary and Coefficients
# On the dynamics of 3d electrified falling films
# On the motion of gravity-capillary waves with odd viscosity
# Generalizaciones de los números : de la aritmética a las variedades diferenciables
# The Concept of the Universe in Physical Cosmology
# Generalized explicit inversive generators of small p-weight degree
# Ruled quartic surfaces, models and classification
# A model for Rayleight-Taylor mixing and interface turnover
# New asymptotic representations of the noncentral t-distribution
# STEAMTEACH Austria: towards a STEAM professional development program
# Low codimension Fano–Enriques threefolds
# On a nonlocal analog of the kuramoto-sivashinsky equation
# A spectral problem for the Laplacian in joined thin films
# Computation of the confluent hypergeometric function U(a,b,x) and its derivative for positive arguments
# Direct symbolic transformation from 3D cartesian into hyperboloidal coordinates
# Classical one-phase Stefan problems for describing polymer crystallization processes
# On bounds for solutions of monotonic first order difference-differential systems

# %% [markdown]
# ### get the article
#   6. **identify** the <span style="color:red">article id</span>
#    - if the id of the articles you search is unknown, you have to browse the results...
#
#    Ex. find an article about 'human' :

# %%
#the term to search is "Human" in the name of the articles
id_articles = find_id(data, "Human")
print(id_articles)
# Out:
# ['2537b71f-2e02-4da6-aa9e-cf2d8725a68e']

# %% [markdown]
#   7. retrieve the <span style="color:red">**article**</span> and its fields<br>
#     - to the REST URL, add **items/[id of the selected item]/metadata** : Return an list of the metadata liked to the article, in JSON

# %%
# get the metadata of the article about Human
address = base_url + "items/" + id_articles[0] + "/metadata"
print("response from "+address)
get_metadata = requests.get(address )
data = get_metadata.json()
# Out:
# response from https://repositorio.unican.es/rest/items/2537b71f-2e02-4da6-aa9e-cf2d8725a68e/metadata

# %%
data
# Out:
# [{'key': 'dc.contributor.author',
#   'value': 'Salomón García, Sergio',
#   'language': '',
#   'element': 'contributor',
#   'qualifier': 'author',
#   'schema': 'dc'},
#  {'key': 'dc.contributor.author',
#   'value': 'Duque Medina, Rafael',
#   'language': '',
#   'element': 'contributor',
#   'qualifier': 'author',
#   'schema': 'dc'},
#  {'key': 'dc.contributor.author',
#   'value': 'Bringas Tejero, Santos',
#   'language': '',
#   'element': 'contributor',
#   'qualifier': 'author',
#   'schema': 'dc'},
#  {'key': 'dc.contributor.author',
#   'value': 'Montaña Arnaiz, José Luis',
#   'language': '',
#   'element': 'contributor',
#   'qualifier': 'author',
#   'schema': 'dc'},
#  {'key': 'dc.contributor.author',
#   'value': 'Lage, Carmen',
#   'language': '',
#   'element': 'contributor',
#   'qualifier': 'author',
#   'schema': 'dc'},
#  {'key': 'dc.contributor.other',
#   'value': 'Universidad de Cantabria',
#   'language': 'es_ES',
#   'element': 'contributor',
#   'qualifier': 'other',
#   'schema': 'dc'},
#  {'key': 'dc.date.accessioned',
#   'value': '2020-03-04T19:13:06Z',
#   'language': '',
#   'element': 'date',
#   'qualifier': 'accessioned',
#   'schema': 'dc'},
#  {'key': 'dc.date.available',
#   'value': '2020-03-04T19:13:06Z',
#   'language': '',
#   'element': 'date',
#   'qualifier': 'available',
#   'schema': 'dc'},
#  {'key': 'dc.date.issued',
#   'value': '2019',
#   'language': '',
#   'element': 'date',
#   'qualifier': 'issued',
#   'schema': 'dc'},
#  {'key': 'dc.identifier.issn',
#   'value': '2504-3900',
#   'language': '',
#   'element': 'identifier',
#   'qualifier': 'issn',
#   'schema': 'dc'},
#  {'key': 'dc.identifier.uri',
#   'value': 'http://hdl.handle.net/10902/18337',
#   'language': '',
#   'element': 'identifier',
#   'qualifier': 'uri',
#   'schema': 'dc'},
#  {'key': 'dc.description.abstract',
#   'value': 'Alzheimer’s disease (AD) constitutes a neurodegenerative pathology that presents mobility disorders as one of its earliest symptoms. Current smartphones integrate accelerometers that can be used to collect mobility data of Alzheimer’s patients. This paper describes a method that processes these accelerometer data and a convolutional neural network (CNN) that classiﬁes the stage of the disease according to the mobility patterns of the patient. The method is applied in a case study with 35 Alzheimer’s patients, in which a classiﬁcation success rate of 91% was obtained',
#   'language': 'es_ES',
#   'element': 'description',
#   'qualifier': 'abstract',
#   'schema': 'dc'},
#  {'key': 'dc.format.extent',
#   'value': '9 p.',
#   'language': 'es_ES',
#   'element': 'format',
#   'qualifier': 'extent',
#   'schema': 'dc'},
#  {'key': 'dc.language.iso',
#   'value': 'eng',
#   'language': 'es_ES',
#   'element': 'language',
#   'qualifier': 'iso',
#   'schema': 'dc'},
#  {'key': 'dc.publisher',
#   'value': 'MDPI',
#   'language': 'es_ES',
#   'element': 'publisher',
#   'qualifier': None,
#   'schema': 'dc'},
#  {'key': 'dc.rights',
#   'value': '© 2019 by the authors. Licensee MDPI, Basel, Switzerland. This article is an open access article distributed under the terms and conditions of the Creative Commons Attribution(CC BY) license.',
#   'language': 'es_ES',
#   'element': 'rights',
#   'qualifier': None,
#   'schema': 'dc'},
#  {'key': 'dc.rights.uri',
#   'value': 'http://creativecommons.org/licenses/by/4.0/',
#   'language': '*',
#   'element': 'rights',
#   'qualifier': 'uri',
#   'schema': 'dc'},
#  {'key': 'dc.source',
#   'value': 'Proceedings 2019, 31(1), 72',
#   'language': 'es_ES',
#   'element': 'source',
#   'qualifier': None,
#   'schema': 'dc'},
#  {'key': 'dc.subject.other',
#   'value': 'Mobile and ubiquitous health',
#   'language': 'es_ES',
#   'element': 'subject',
#   'qualifier': 'other',
#   'schema': 'dc'},
#  {'key': 'dc.subject.other',
#   'value': 'Alzheimer',
#   'language': 'es_ES',
#   'element': 'subject',
#   'qualifier': 'other',
#   'schema': 'dc'},
#  {'key': 'dc.subject.other',
#   'value': 'Convolutional neural network',
#   'language': 'es_ES',
#   'element': 'subject',
#   'qualifier': 'other',
#   'schema': 'dc'},
#  {'key': 'dc.title',
#   'value': 'A Convolutional Neural Network-Based Method for Human Movement Patterns Classification in Alzheimer?s Disease',
#   'language': 'es_ES',
#   'element': 'title',
#   'qualifier': None,
#   'schema': 'dc'},
#  {'key': 'dc.type',
#   'value': 'info:eu-repo/semantics/conferenceObject',
#   'language': 'es_ES',
#   'element': 'type',
#   'qualifier': None,
#   'schema': 'dc'},
#  {'key': 'dc.relation.publisherVersion',
#   'value': 'https://doi.org/10.3390/proceedings2019031072',
#   'language': 'es_ES',
#   'element': 'relation',
#   'qualifier': 'publisherVersion',
#   'schema': 'dc'},
#  {'key': 'dc.rights.accessRights',
#   'value': 'openAccess',
#   'language': 'es_ES',
#   'element': 'rights',
#   'qualifier': 'accessRights',
#   'schema': 'dc'},
#  {'key': 'dc.type.version',
#   'value': 'acceptedVersion',
#   'language': 'es_ES',
#   'element': 'type',
#   'qualifier': 'version',
#   'schema': 'dc'}]

# %%
def get_data_article(data):
    """from data about an article in the JSON format of repositorio.unican.es, get the authors, title and abstract"""
    authors = []
    title = ""
    abstract = ""
    source = ""
    date = ""

    for item in data:
        if item['key'] == 'dc.contributor.author':
            authors.append(item['value'])
        elif item['key'] == 'dc.title':
            title = item['value']
        elif item['key'] == 'dc.source':
            source = item['value']
        elif item['key'] == 'dc.date.issued':
            date = item['value']
        elif item['key'] == 'dc.description.abstract':
            abstract = item['value']

    print("Authors :", authors)
    print("Titre :", title)
    print("In :", source)
    print("Date :", date)
    print("Abstract :", abstract)

# %%
get_data_article(data)
# Out:
# Authors : ['Salomón García, Sergio', 'Duque Medina, Rafael', 'Bringas Tejero, Santos', 'Montaña Arnaiz, José Luis', 'Lage, Carmen']
# Titre : A Convolutional Neural Network-Based Method for Human Movement Patterns Classification in Alzheimer?s Disease
# In : Proceedings 2019, 31(1), 72
# Date : 2019
# Abstract : Alzheimer’s disease (AD) constitutes a neurodegenerative pathology that presents mobility disorders as one of its earliest symptoms. Current smartphones integrate accelerometers that can be used to collect mobility data of Alzheimer’s patients. This paper describes a method that processes these accelerometer data and a convolutional neural network (CNN) that classiﬁes the stage of the disease according to the mobility patterns of the patient. The method is applied in a case study with 35 Alzheimer’s patients, in which a classiﬁcation success rate of 91% was obtained

# %% [markdown]
# -----
# ### Documentation DSpace says that the REST Api adopt the HAL format...
# We try
#
# https://repositorio.unican.es/rest/filtered-items/?q=Human

# %%
base_url = "https://repositorio.unican.es/rest/"

# %%
#query found 'agent' in the abstract 
query='abstract_t:(human)'


param_filters = {
        "filter" : "author",
        "operator" : "authority",
        "label" : "Paulo"
      }

# %%
# GET request
param_filters = "?limit=3&expand=metadata&query=agent"
##PB query doesn't seems to work
url = base_url+"items"+param_filters
response = requests.get(url)
#response = requests.get(base_url)

# %%
print("response from "+url)
data = response.json()
len(data)
# Out:
# response from https://repositorio.unican.es/rest/items?limit=3&expand=metadata&query=agent
# 3

# %%
for d in data: print(d['name'])
# Out:
# Comportamiento como desulfurantes de diferentes sorbentes a baja (58ºC) y media (150ºC) temperatura
# Electromagnetic behavior of plasmonic devices with nanoholes. Biosensing applications
# Analysis of superregenerative oscillators in nonlinear mode

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n            <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->\n            <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->\n            <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->\n            <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->\n            <head><META http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<meta content="text/html; charset=UTF-8" http-equiv="Content-Type">\n<meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">\n<meta content="width=device-width,initial-scale=1" name="viewport">\n<meta name="Author" content="UCrea Repositorio abierto de la Universidad de Cantabria">\n<meta name="Copyright" content="UCrea Repositorio abierto de la Universidad de Cantabria">\n<meta name="Publisher" content="UCrea Repositorio abierto de la Universidad de Cantabria">\n<link rel="shortcut icon" href="/xmlui/themes/Mirage2/images/favicon.ico">\n<link rel="apple-touch-icon" href="/xmlui/themes/Mirage2/images/apple-touch-icon.png">\n<meta name="Generator" content="DSpace 6.4_1.1.4">\n<link href="/xmlui/themes/Mirage2/styles/main.css" rel="stylesheet">\n<link type="application/opensearchdescription+xml" rel="search" href="https://repositorio.unican.es:443/xmlui/description.xml" title="DSpace">\n<script>\n                //Clear default text of emty text areas on focus\n                function tFocus(element)\n                {\n                if (element.value == \' \'){element.value=\'\';}\n                }\n                //Clear default text of emty text areas on submit\n                function tSubmit(form)\n                {\n                var defaultedElements = document.getElementsByTagName("textarea");\n                for (var i=0; i != defaultedElements.length; i++){\n                if (defaultedElements[i].value == \' \'){\n                defaultedElements[i].value=\'\';}}\n                }\n                //Disable pressing \'enter\' key to submit a form (otherwise pressing \'enter\' causes a submission to start over)\n                function disableEnterKey(e)\n                {\n                var key;\n\n                if(window.event)\n                key = window.event.keyCode;     //Internet Explorer\n                else\n                key = e.which;     //Firefox and Netscape\n\n                if(key == 13)  //if "Enter" pressed, then disable!\n                return false;\n                else\n                return true;\n                }\n            </script><!--[if lt IE 9]>\n            <script src="/xmlui/themes/Mirage2/scripts/html5shiv.js">\xc2\xa0</script>\n            <script src="/xmlui/themes/Mirage2/scripts/respond.min.js">\xc2\xa0</script>\n                <![endif]--><title>Buscar</title>\n</head><body>\n<header>\n<div role="navigation" class="navbar navbar-default navbar-static-top">\n<div class="container">\n<div class="navbar-header">\n<button data-toggle="offcanvas" class="navbar-toggle" type="button"><span class="sr-only">Toggle navigation</span><span class="icon-bar"></span><span class="icon-bar"></span><span class="icon-bar"></span></button><a class="navbar-brand banner-uc" href="/xmlui/"><img src="/xmlui/themes/Mirage2//images/UCrea/pc/banner_ucrea.jpg"></a><a target="_blank" class="navbar-brand logo-uc" href="https://web.unican.es/"><img src="/xmlui/themes/Mirage2//images/UCrea/pc/uc_neg_verde.png"></a>\n<div class="navbar-header pull-right visible-xs hidden-sm hidden-md hidden-lg">\n<ul class="nav nav-pills pull-left ">\n<li>\n<form method="get" action="/xmlui/login" style="display: inline">\n<button class="navbar-toggle navbar-link"><b aria-hidden="true" class="visible-xs glyphicon glyphicon-user"></b></button>\n</form>\n</li>\n</ul>\n</div>\n</div>\n<div class="navbar-header pull-right hidden-xs">\n<ul class="nav navbar-nav pull-left"></ul>\n<ul class="nav navbar-nav pull-left">\n<li>\n<a href="/xmlui/login"><span  ...

# %% [markdown]
# ---
# ## <a name="SINUS">SINUS</a>
# Api not easy to use, some queries necessitate a login:
#
# - articles about multiagent :
# https://sin.put.poznan.pl/search/publications?personName=&personId=-1&phrase=multiagent&page=1&organizationName=&organizationId=-1&type=all&disciplineCode=&yearFrom=2004&yearTo=2024&waitingForApproval=false&hasContent=false&perPage=100&sortBy=publication-date-desc
# - cf. doc about api : https://docs.psnc.pl/display/SIN1/SIN+API
